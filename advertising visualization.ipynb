# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('C:/Users/WIN-10/OneDrive/Desktop/Advertising.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.shape
# Out:
# (200, 5)

# %%
sns.distplot(data['TV'])
sns.distplot(data['Radio'])

# %%
sns.kdeplot(data.TV,bw=100,label='TV')
sns.kdeplot(data.Radio,bw=100,label='Radio')
sns.kdeplot(data.Newspaper,bw=100,label='newspaper')

# %%
sns.relplot('TV','Sales',data=data,kind='line')
